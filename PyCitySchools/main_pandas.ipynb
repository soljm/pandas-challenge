# %% [markdown]
# # Module 4 Challenge - Pandas

# %% [markdown]
# ## Analysis

# %% [markdown]
# add analysis here

# %% [markdown]
# ## Setup

# %%
# setup
from pathlib import Path
import pandas as pd

# %%
# set path
school_file = Path("../Resources/schools_complete.csv")
students_file = Path("../Resources/students_complete.csv")

# read and store in DataFrames (DF)
school_df = pd.read_csv(school_file, encoding='utf-8').set_index(["school_name"])
students_df = pd.read_csv(students_file, encoding='utf-8')

# merge into one DF
complete_df = pd.merge(school_df, students_df, how="left", on=["school_name", "school_name"])
complete_df
# Out:
#               school_name  School ID         type  size   budget  Student ID  \
# 0       Huang High School          0   Government  2917  1910635           0
# 1       Huang High School          0   Government  2917  1910635           1
# 2       Huang High School          0   Government  2917  1910635           2
# 3       Huang High School          0   Government  2917  1910635           3
# 4       Huang High School          0   Government  2917  1910635           4
# ...                   ...        ...          ...   ...      ...         ...
# 39165  Thomas High School         14  Independent  1635  1043130       39165
# 39166  Thomas High School         14  Independent  1635  1043130       39166
# 39167  Thomas High School         14  Independent  1635  1043130       39167
# 39168  Thomas High School         14  Independent  1635  1043130       39168
# 39169  Thomas High School         14  Independent  1635  1043130       39169
#
# ...

# %% [markdown]
# ## Local Government Area (LGA) Summary

# %%
# calculate totals 
# total unique schools
school_count = complete_df['school_name'].nunique()
print("Total unique schools: " + str(school_count))

# total students
student_count = complete_df["student_name"].count()
print("Total students: " + str(student_count))

# total budget
total_budget = school_df["budget"].sum()
print("Total budget: " + str(total_budget))
# Out:
# Total unique schools: 15
# Total students: 39170
# Total budget: 24649428

# %%
# calculate averages
# average maths score
avg_maths = complete_df["maths_score"].mean()
avg_maths = avg_maths.round(decimals = 2)
print("Average maths score: " + str(avg_maths))

#average reading score
avg_reading = complete_df["reading_score"].mean()
avg_reading = avg_reading.round(decimals = 2)
print("Average reading score: " + str(avg_reading))
# Out:
# Average maths score: 70.34
# Average reading score: 69.98

# %%
# calculate % passing 
# % passing maths
passing_maths = complete_df[complete_df["maths_score"] >= 50]["student_name"].count()
passing_maths_percent = (passing_maths / float(student_count)) * 100
print("Percentage of students passing maths: " + str(passing_maths_percent) + "%")

# % passing reading
passing_reading = complete_df[complete_df["reading_score"] >= 50]["student_name"].count()
passing_reading_percent = (passing_reading / float(student_count)) * 100
print("Percentage of students passing reading: " + str(passing_reading_percent) + "%")

# % overall passing
passing_overall = complete_df[(complete_df["reading_score"] >= 50) & (complete_df["maths_score"] >= 50)]["student_name"].count()
passing_overall_percent = (passing_overall / float(student_count)) * 100
print("Percentage of students passing reading: " + str(passing_overall_percent) + "%")
# Out:
# Percentage of students passing maths: 86.07863160582077%
# Percentage of students passing reading: 84.42685728874139%
# Percentage of students passing reading: 72.80827163645647%

# %%
# convert to DF
area_summary = pd.DataFrame({"Total Unique Schools": school_count,
                             "Total Students": student_count,
                             "Total Budget": total_budget,
                             "Average Maths Score": avg_maths,
                             "Average Reading Score": avg_reading,
                             "% Passing Maths": passing_maths_percent,
                             "% Passing Reading": passing_reading_percent,
                             "% Overall Passing": passing_overall_percent}, index=[0])
# formatting
area_summary["Total Students"] = area_summary["Total Students"].map("{:,}".format)
area_summary["Total Budget"] = area_summary["Total Budget"].map("${:,.2f}".format)
area_summary["% Passing Maths"] = area_summary["% Passing Maths"].map("{:,.2f}%".format)
area_summary["% Passing Reading"] = area_summary["% Passing Reading"].map("{:,.2f}%".format)
area_summary["% Overall Passing"] = area_summary["% Overall Passing"].map("{:,.2f}%".format)

# print
area_summary
# Out:
#    Total Unique Schools Total Students    Total Budget  Average Maths Score  \
# 0                    15         39,170  $24,649,428.00                70.34
#
#    Average Reading Score % Passing Maths % Passing Reading % Overall Passing
# 0                  69.98          86.08%            84.43%            72.81%

# %% [markdown]
# ## School Summary

# %%
# use code provided to select type of school from school_df
school_types = school_df["type"]
school_types
# Out:
# school_name
# Huang High School         Government
# Figueroa High School      Government
# Shelton High School      Independent
# Hernandez High School     Government
# Griffin High School      Independent
# Wilson High School       Independent
# Cabrera High School      Independent
# Bailey High School        Government
# Holden High School       Independent
# Pena High School         Independent
# Wright High School       Independent
# Rodriguez High School     Government
# Johnson High School       Government
# Ford High School          Government
# Thomas High School       Independent
# Name: type, dtype: object

# %%
# calculate totals
# total students
students_per_school = school_df["size"]
students_per_school
# Out:
# school_name
# Huang High School        2917
# Figueroa High School     2949
# Shelton High School      1761
# Hernandez High School    4635
# Griffin High School      1468
# Wilson High School       2283
# Cabrera High School      1858
# Bailey High School       4976
# Holden High School        427
# Pena High School          962
# Wright High School       1800
# Rodriguez High School    3999
# Johnson High School      4761
# Ford High School         2739
# Thomas High School       1635
# Name: size, dtype: int64

# %%
# total school budget
total_school_budget = school_df["budget"]
total_school_budget
# Out:
# school_name
# Huang High School        1910635
# Figueroa High School     1884411
# Shelton High School      1056600
# Hernandez High School    3022020
# Griffin High School       917500
# Wilson High School       1319574
# Cabrera High School      1081356
# Bailey High School       3124928
# Holden High School        248087
# Pena High School          585858
# Wright High School       1049400
# Rodriguez High School    2547363
# Johnson High School      3094650
# Ford High School         1763916
# Thomas High School       1043130
# Name: budget, dtype: int64

# %%
# budget per student
budget_per_student = total_school_budget / students_per_school
budget_per_student
# Out:
# school_name
# Huang High School        655.0
# Figueroa High School     639.0
# Shelton High School      600.0
# Hernandez High School    652.0
# Griffin High School      625.0
# Wilson High School       578.0
# Cabrera High School      582.0
# Bailey High School       628.0
# Holden High School       581.0
# Pena High School         609.0
# Wright High School       583.0
# Rodriguez High School    637.0
# Johnson High School      650.0
# Ford High School         644.0
# Thomas High School       638.0
# dtype: float64

# %%
# groupby school name
school_grouped_df = complete_df.groupby(["school_name"])

# average maths score 
per_avg_math = school_grouped_df["maths_score"].mean()
per_avg_math = per_avg_math.round(decimals=2)
per_avg_math
# Out:
# school_name
# Bailey High School       72.35
# Cabrera High School      71.66
# Figueroa High School     68.70
# Ford High School         69.09
# Griffin High School      71.79
# Hernandez High School    68.87
# Holden High School       72.58
# Huang High School        68.94
# Johnson High School      68.84
# Pena High School         72.09
# Rodriguez High School    72.05
# Shelton High School      72.03
# Thomas High School       69.58
# Wilson High School       69.17
# Wright High School       72.05
# Name: maths_score, dtype: float64

# %%
# average reading score 
per_avg_reading = school_grouped_df["reading_score"].mean()
per_avg_reading = per_avg_reading.round(decimals=2)
per_avg_reading
# Out:
# school_name
# Bailey High School       71.01
# Cabrera High School      71.36
# Figueroa High School     69.08
# Ford High School         69.57
# Griffin High School      71.25
# Hernandez High School    69.19
# Holden High School       71.66
# Huang High School        68.91
# Johnson High School      69.04
# Pena High School         71.61
# Rodriguez High School    70.94
# Shelton High School      70.26
# Thomas High School       69.77
# Wilson High School       68.88
# Wright High School       70.97
# Name: reading_score, dtype: float64

# %%
# total students passing maths
per_pass_maths = complete_df[complete_df["maths_score"] >= 50]
per_pass_maths = per_pass_maths.groupby(["school_name"])
per_pass_maths = per_pass_maths["student_name"].count()
per_pass_maths
# Out:
# school_name
# Bailey High School       4560
# Cabrera High School      1688
# Figueroa High School     2408
# Ford High School         2258
# Griffin High School      1339
# Hernandez High School    3752
# Holden High School        384
# Huang High School        2383
# Johnson High School      3907
# Pena High School          882
# Rodriguez High School    3631
# Shelton High School      1612
# Thomas High School       1371
# Wilson High School       1890
# Wright High School       1652
# Name: student_name, dtype: int64

# %%
# % passing maths
per_percent_maths = (per_pass_maths / students_per_school) * 100
per_percent_maths
# Out:
# school_name
# Bailey High School       91.639871
# Cabrera High School      90.850377
# Figueroa High School     81.654798
# Ford High School         82.438846
# Griffin High School      91.212534
# Hernandez High School    80.949299
# Holden High School       89.929742
# Huang High School        81.693521
# Johnson High School      82.062592
# Pena High School         91.683992
# Rodriguez High School    90.797699
# Shelton High School      91.538898
# Thomas High School       83.853211
# Wilson High School       82.785808
# Wright High School       91.777778
# dtype: float64

# %%
# total students passing reading
per_pass_reading = complete_df[complete_df["reading_score"] >= 50]
per_pass_reading = per_pass_reading.groupby(["school_name"])
per_pass_reading = per_pass_reading["student_name"].count()
per_pass_reading
# Out:
# school_name
# Bailey High School       4348
# Cabrera High School      1655
# Figueroa High School     2442
# Ford High School         2252
# Griffin High School      1299
# Hernandez High School    3795
# Holden High School        378
# Huang High School        2376
# Johnson High School      3903
# Pena High School          833
# Rodriguez High School    3495
# Shelton High School      1527
# Thomas High School       1351
# Wilson High School       1856
# Wright High School       1560
# Name: student_name, dtype: int64

# %%
# % passing reading
per_percent_reading = (per_pass_reading / students_per_school) * 100
per_percent_reading
# Out:
# school_name
# Bailey High School       87.379421
# Cabrera High School      89.074273
# Figueroa High School     82.807731
# Ford High School         82.219788
# Griffin High School      88.487738
# Hernandez High School    81.877023
# Holden High School       88.524590
# Huang High School        81.453548
# Johnson High School      81.978576
# Pena High School         86.590437
# Rodriguez High School    87.396849
# Shelton High School      86.712095
# Thomas High School       82.629969
# Wilson High School       81.296540
# Wright High School       86.666667
# dtype: float64

# %%
# total students passing maths and reading
per_pass_overall = complete_df[(complete_df["reading_score"] >= 50) & (complete_df["maths_score"] >= 50)]
per_pass_overall = per_pass_overall.groupby(["school_name"])
per_pass_overall = per_pass_overall["student_name"].count()
per_pass_overall
# Out:
# school_name
# Bailey High School       3985
# Cabrera High School      1501
# Figueroa High School     1995
# Ford High School         1848
# Griffin High School      1194
# Hernandez High School    3076
# Holden High School        337
# Huang High School        1946
# Johnson High School      3199
# Pena High School          762
# Rodriguez High School    3176
# Shelton High School      1389
# Thomas High School       1136
# Wilson High School       1540
# Wright High School       1435
# Name: student_name, dtype: int64

# %%
# % passing reading and maths
per_percent_overall = (per_pass_overall / students_per_school) * 100
per_percent_overall
# Out:
# school_name
# Bailey High School       80.084405
# Cabrera High School      80.785791
# Figueroa High School     67.650051
# Ford High School         67.469880
# Griffin High School      81.335150
# Hernandez High School    66.364617
# Holden High School       78.922717
# Huang High School        66.712376
# Johnson High School      67.191766
# Pena High School         79.209979
# Rodriguez High School    79.419855
# Shelton High School      78.875639
# Thomas High School       69.480122
# Wilson High School       67.455103
# Wright High School       79.722222
# dtype: float64

# %%
# create DF
school_summary = pd.DataFrame({"School Type": school_types,
                             "Total Students": students_per_school,
                             "Total School Budget": total_school_budget,
                             "Budget Per Student": budget_per_student,
                             "Average Maths Score": per_avg_math,
                             "Average Reading Score": per_avg_reading,
                             "% Passing Maths": per_percent_maths,
                             "% Passing Reading": per_percent_reading,
                             "% Overall Passing": per_percent_overall})

# formatting
school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,.2f}".format)
school_summary["Budget Per Student"] = school_summary["Budget Per Student"].map("${:,.2f}".format)
school_summary["% Passing Maths"] = school_summary["% Passing Maths"].map("{:,.2f}%".format)
school_summary["% Passing Reading"] = school_summary["% Passing Reading"].map("{:,.2f}%".format)
school_summary["% Overall Passing"] = school_summary["% Overall Passing"].map("{:,.2f}%".format)

school_summary
# Out:
#                        School Type  Total Students Total School Budget  \
# school_name
# Bailey High School      Government            4976       $3,124,928.00
# Cabrera High School    Independent            1858       $1,081,356.00
# Figueroa High School    Government            2949       $1,884,411.00
# Ford High School        Government            2739       $1,763,916.00
# Griffin High School    Independent            1468         $917,500.00
# Hernandez High School   Government            4635       $3,022,020.00
# Holden High School     Independent             427         $248,087.00
# Huang High School       Government            2917       $1,910,635.00
# Johnson High School     Government            4761       $3,094,650.00
# Pena High School       Independent             962         $585,858.00
# Rodriguez High School   Government            3999       $2,547,363.00
# Shelton High School    Independent            1761       $1,056,600.00
# ...

# %% [markdown]
# ## Highest-Performing Schools (by % Overall Passing)

# %%
# find top performing schools
# sort DF highest to lowest
top_schools = school_summary.sort_values(by="% Overall Passing", ascending=False)

# format
top_schools["Total School Budget"] = top_schools["Total School Budget"].map("${:,.2f}".format)
top_schools["Budget Per Student"] = top_schools["Budget Per Student"].map("${:,.2f}".format)
top_schools["% Passing Maths"] = top_schools["% Passing Maths"].map("{:,.2f}%".format)
top_schools["% Passing Reading"] = top_schools["% Passing Reading"].map("{:,.2f}%".format)
top_schools["% Overall Passing"] = top_schools["% Overall Passing"].map("{:,.2f}%".format)

top_schools.head(5)
# Out:
#                        School Type  Total Students Total School Budget  \
# school_name
# Griffin High School    Independent            1468         $917,500.00
# Cabrera High School    Independent            1858       $1,081,356.00
# Bailey High School      Government            4976       $3,124,928.00
# Wright High School     Independent            1800       $1,049,400.00
# Rodriguez High School   Government            3999       $2,547,363.00
#
#                       Budget Per Student  Average Maths Score  \
# school_name
# Griffin High School              $625.00                71.79
# Cabrera High School              $582.00                71.66
# Bailey High School               $628.00                72.35
# Wright High School               $583.00                72.05
# Rodriguez High School            $637.00                72.05
#
#                        Average Reading Score % Passing Maths  \
# school_name
# ...

# %% [markdown]
# ## Lowest-Performing Schools (by % Overall Passing)

# %%
# find bottom performing schools
# sort DF lowest to highest
bottom_schools = school_summary.sort_values(by="% Overall Passing")

# format
bottom_schools["Total School Budget"] = bottom_schools["Total School Budget"].map("${:,.2f}".format)
bottom_schools["Budget Per Student"] = bottom_schools["Budget Per Student"].map("${:,.2f}".format)
bottom_schools["% Passing Maths"] = bottom_schools["% Passing Maths"].map("{:,.2f}%".format)
bottom_schools["% Passing Reading"] = bottom_schools["% Passing Reading"].map("{:,.2f}%".format)
bottom_schools["% Overall Passing"] = bottom_schools["% Overall Passing"].map("{:,.2f}%".format)

bottom_schools.head(5)
# Out:
#                        School Type  Total Students Total School Budget  \
# school_name
# Hernandez High School   Government            4635       $3,022,020.00
# Huang High School       Government            2917       $1,910,635.00
# Johnson High School     Government            4761       $3,094,650.00
# Wilson High School     Independent            2283       $1,319,574.00
# Ford High School        Government            2739       $1,763,916.00
#
#                       Budget Per Student  Average Maths Score  \
# school_name
# Hernandez High School            $652.00                68.87
# Huang High School                $655.00                68.94
# Johnson High School              $650.00                68.84
# Wilson High School               $578.00                69.17
# Ford High School                 $644.00                69.09
#
#                        Average Reading Score % Passing Maths  \
# school_name
# ...

# %% [markdown]
# ## Maths Scores by Year

# %%
# groupby school name and year
school_year_group = complete_df.groupby(["school_name", "year"])

# maths scores
maths_year_school = school_year_group["maths_score"].mean()
maths_year_school = maths_year_school.round(decimals=2)
maths_year_school = maths_year_school.unstack()

maths_year_school
# Out:
# year                      9      10     11     12
# school_name
# Bailey High School     72.49  71.90  72.37  72.68
# Cabrera High School    72.32  72.44  71.01  70.60
# Figueroa High School   68.48  68.33  68.81  69.33
# Ford High School       69.02  69.39  69.25  68.62
# Griffin High School    72.79  71.09  71.69  71.47
# Hernandez High School  68.59  68.87  69.15  68.99
# Holden High School     70.54  75.11  71.64  73.41
# Huang High School      69.08  68.53  69.43  68.64
# Johnson High School    69.47  67.99  68.64  69.29
# Pena High School       72.00  72.40  72.52  71.19
# Rodriguez High School  71.94  71.78  72.36  72.15
# Shelton High School    72.93  72.51  70.10  72.33
# Thomas High School     69.23  70.06  69.66  69.37
# Wilson High School     69.21  69.46  68.38  69.79
# Wright High School     71.74  72.18  73.28  70.85

# %% [markdown]
# ## Reading Scores by Year

# %%
# reading scores
reading_year_school = school_year_group["reading_score"].mean()
reading_year_school = reading_year_school.round(decimals=2)
reading_year_school = reading_year_school.unstack()

reading_year_school
# Out:
# year                      9      10     11     12
# school_name
# Bailey High School     70.90  70.85  70.32  72.20
# Cabrera High School    71.17  71.33  71.20  71.86
# Figueroa High School   70.26  67.68  69.15  69.08
# Ford High School       69.62  68.99  70.74  68.85
# Griffin High School    72.03  70.75  72.39  69.43
# Hernandez High School  68.48  70.62  68.42  69.24
# Holden High School     71.60  71.10  73.31  70.48
# Huang High School      68.67  69.52  68.74  68.67
# Johnson High School    68.72  69.30  69.97  67.99
# Pena High School       70.95  72.32  71.70  71.51
# Rodriguez High School  70.90  70.14  71.42  71.41
# Shelton High School    70.72  69.88  71.15  69.07
# Thomas High School     69.67  69.74  70.75  68.73
# Wilson High School     68.68  68.41  68.80  69.89
# Wright High School     71.82  71.39  70.48  69.82

# %% [markdown]
# ## Scores by School Spending

# %%
# establish the bins
spending_bins = [0, 585, 630, 645, 680]
group_names = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
# categorise into bins
school_summary["Spending Ranges (Per Student)"] = pd.cut(school_summary["Budget Per Student"], spending_bins, labels=group_names)
school_summary
# Out:
#                        School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School      Government            4976              3124928
# Cabrera High School    Independent            1858              1081356
# Figueroa High School    Government            2949              1884411
# Ford High School        Government            2739              1763916
# Griffin High School    Independent            1468               917500
# Hernandez High School   Government            4635              3022020
# Holden High School     Independent             427               248087
# Huang High School       Government            2917              1910635
# Johnson High School     Government            4761              3094650
# Pena High School       Independent             962               585858
# Rodriguez High School   Government            3999              2547363
# Shelton High School    Independent            1761              1056600
# ...

# %%
#  Calculate averages for the desired columns.
spending_maths_scores = school_summary.groupby(["Spending Ranges (Per Student)"])["Average Maths Score"].mean()
spending_reading_scores = school_summary.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
spending_passing_maths = school_summary.groupby(["Spending Ranges (Per Student)"])["% Passing Maths"].mean()
spending_passing_reading = school_summary.groupby(["Spending Ranges (Per Student)"])["% Passing Reading"].mean()
overall_passing_spending = school_summary.groupby(["Spending Ranges (Per Student)"])["% Overall Passing"].mean()
# Out:
# /var/folders/05/t0264j8s193_l6tv6jy3yryh0000gp/T/ipykernel_9224/4100028608.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spending_maths_scores = school_summary.groupby(["Spending Ranges (Per Student)"])["Average Maths Score"].mean()
# /var/folders/05/t0264j8s193_l6tv6jy3yryh0000gp/T/ipykernel_9224/4100028608.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spending_reading_scores = school_summary.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
# ...

# %%
# create DF
spending_summary = pd.DataFrame({"Average Maths Score": spending_maths_scores.map("{:,.2f}".format),
                                 "Average Reading Score": spending_reading_scores.map("{:,.2f}".format),
                                 "% Passing Maths": spending_passing_maths.map("{:,.2f}%".format),
                                 "% Passing Reading": spending_passing_reading.map("{:,.2f}%".format),
                                 "% Overall Passing": overall_passing_spending.map("{:,.2f}%".format)})

spending_summary
# Out:
#                               Average Maths Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                       71.36                 70.72
# $585-630                                    72.06                 71.03
# $630-645                                    69.86                 69.84
# $645-680                                    68.88                 69.05
#
#                               % Passing Maths % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                  88.84%            86.39%
# $585-630                               91.52%            87.29%
# $630-645                               84.69%            83.76%
# $645-680                               81.57%            81.77%
#
#                               % Overall Passing
# Spending Ranges (Per Student)
# <$585                                    76.72%
# $585-630                                 79.88%
# ...

# %% [markdown]
# ## Scores By School Size

# %%
# establish the bins.
size_bins = [0, 1000, 2000, 5000]
group_names2 = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# categorize the spending based on the bins
school_summary["School Size"] = pd.cut(school_summary["Total Students"], size_bins, labels=group_names2)
school_summary
# Out:
#                        School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School      Government            4976              3124928
# Cabrera High School    Independent            1858              1081356
# Figueroa High School    Government            2949              1884411
# Ford High School        Government            2739              1763916
# Griffin High School    Independent            1468               917500
# Hernandez High School   Government            4635              3022020
# Holden High School     Independent             427               248087
# Huang High School       Government            2917              1910635
# Johnson High School     Government            4761              3094650
# Pena High School       Independent             962               585858
# Rodriguez High School   Government            3999              2547363
# Shelton High School    Independent            1761              1056600
# ...

# %%
# calculate averages for the desired columns.
size_maths_scores = school_summary.groupby(["School Size"])["Average Maths Score"].mean()
size_reading_scores = school_summary.groupby(["School Size"])["Average Reading Score"].mean()
size_passing_maths = school_summary.groupby(["School Size"])["% Passing Maths"].mean()
size_passing_reading = school_summary.groupby(["School Size"])["% Passing Reading"].mean()
size_overall_passing = school_summary.groupby(["School Size"])["% Overall Passing"].mean()
# Out:
# /var/folders/05/t0264j8s193_l6tv6jy3yryh0000gp/T/ipykernel_9224/3169729628.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   size_maths_scores = school_summary.groupby(["School Size"])["Average Maths Score"].mean()
# /var/folders/05/t0264j8s193_l6tv6jy3yryh0000gp/T/ipykernel_9224/3169729628.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   size_reading_scores = school_summary.groupby(["School Size"])["Average Reading Score"].mean()
# ...

# %%
# create DF
size_summary = pd.DataFrame({"Average Maths Score": size_maths_scores.map("{:,.2f}".format),
                             "Average Reading Score": size_reading_scores.map("{:,.2f}".format),
                             "% Passing Maths": size_passing_maths.map("{:,.2f}%".format),
                             "% Passing Reading": size_passing_reading.map("{:,.2f}%".format),
                             "% Overall Passing": size_overall_passing.map("{:,.2f}%".format)})

size_summary
# Out:
#                    Average Maths Score Average Reading Score % Passing Maths  \
# School Size
# Small (<1000)                    72.34                 71.63          90.81%
# Medium (1000-2000)               71.42                 70.72          89.85%
# Large (2000-5000)                69.75                 69.58          84.25%
#
#                    % Passing Reading % Overall Passing
# School Size
# Small (<1000)                 87.56%            79.07%
# Medium (1000-2000)            86.71%            78.04%
# Large (2000-5000)             83.30%            70.29%

# %% [markdown]
# ## Scores By School Type

# %%
# Create new series using groupby for:
# Type | Average Maths Score | Average Reading Score | % Passing Maths | % Passing Reading | % Overall Passing

type_maths_scores = school_summary.groupby(["School Type"])["Average Maths Score"].mean()
type_reading_scores = school_summary.groupby(["School Type"])["Average Reading Score"].mean()
type_passing_maths = school_summary.groupby(["School Type"])["% Passing Maths"].mean()
type_passing_reading = school_summary.groupby(["School Type"])["% Passing Reading"].mean()
type_overall_passing = school_summary.groupby(["School Type"])["% Overall Passing"].mean()

# %%
# create DF
type_summary = pd.DataFrame({"Average Maths Score": type_maths_scores.map("{:,.2f}".format),
                             "Average Reading Score": type_reading_scores.map("{:,.2f}".format),
                             "% Passing Maths": type_passing_maths.map("{:,.2f}%".format),
                             "% Passing Reading": type_passing_reading.map("{:,.2f}%".format),
                             "% Overall Passing": type_overall_passing.map("{:,.2f}%".format)})

type_summary
# Out:
#             Average Maths Score Average Reading Score % Passing Maths  \
# School Type
# Government                69.83                 69.68          84.46%
# Independent               71.37                 70.72          89.20%
#
#             % Passing Reading % Overall Passing
# School Type
# Government             83.59%            70.70%
# Independent            86.25%            76.97%
